# %%
import pandas as pd

df = pd.read_csv('/home/ksb/Downloads/data(1).csv')

print(df.to_string())
# Out:
#     Duration  Pulse  Maxpulse  Calories        Date
# 0         60    110       130     409.1  01/01/2015
# 1         60    117       145     479.0  01/01/2015
# 2         60    103       135     340.0  02/01/2015
# 3         45    109       175     282.4  03/01/2015
# 4         45    117       148     406.0  04/01/2015
# 5         60    102       127     300.0  05/01/2015
# 6         60    110       136     374.0  06/01/2015
# 7         45    104       134     253.3  07/01/2015
# 8         30    109       133     195.1  08/01/2015
# 9         60     98       124     269.0  09/01/2015
# 10        60    103       147     329.3  10/01/2015
# 11        60    100       120     250.7  07/01/2015
# 12        60    106       128     345.3  12/01/2015
# 13        60    104       132     379.3  13/01/2015
# 14        60     98       123     275.0  14/01/2015
# 15        60     98       120     215.2  15/01/2015
# 16        60    100       120     300.0  15/01/2015
# ...

# %%
import pandas as pd

df = pd.read_csv('/home/ksb/Downloads/data(1).csv')

new_df = df.dropna()

print(new_df.to_string())
# Out:
#     Duration  Pulse  Maxpulse  Calories        Date
# 0         60    110       130     409.1  01/01/2015
# 1         60    117       145     479.0  01/01/2015
# 2         60    103       135     340.0  02/01/2015
# 3         45    109       175     282.4  03/01/2015
# 4         45    117       148     406.0  04/01/2015
# 5         60    102       127     300.0  05/01/2015
# 6         60    110       136     374.0  06/01/2015
# 7         45    104       134     253.3  07/01/2015
# 8         30    109       133     195.1  08/01/2015
# 9         60     98       124     269.0  09/01/2015
# 10        60    103       147     329.3  10/01/2015
# 11        60    100       120     250.7  07/01/2015
# 12        60    106       128     345.3  12/01/2015
# 13        60    104       132     379.3  13/01/2015
# 14        60     98       123     275.0  14/01/2015
# 15        60     98       120     215.2  15/01/2015
# 16        60    100       120     300.0  15/01/2015
# ...

# %%
import pandas as pd

df = pd.read_csv('/home/ksb/Downloads/data(1).csv')
x = df["Calories"].mean()

df["Calories"].fillna(x, inplace = True) 
print(df.to_string())
# Out:
#     Duration  Pulse  Maxpulse    Calories        Date
# 0         60    110       130  409.100000  01/01/2015
# 1         60    117       145  479.000000  01/01/2015
# 2         60    103       135  340.000000  02/01/2015
# 3         45    109       175  282.400000  03/01/2015
# 4         45    117       148  406.000000  04/01/2015
# 5         60    102       127  300.000000  05/01/2015
# 6         60    110       136  374.000000  06/01/2015
# 7         45    104       134  253.300000  07/01/2015
# 8         30    109       133  195.100000  08/01/2015
# 9         60     98       124  269.000000  09/01/2015
# 10        60    103       147  329.300000  10/01/2015
# 11        60    100       120  250.700000  07/01/2015
# 12        60    106       128  345.300000  12/01/2015
# 13        60    104       132  379.300000  13/01/2015
# 14        60     98       123  275.000000  14/01/2015
# 15        60     98       120  215.200000  15/01/2015
# ...

# %%
import pandas as pd

df = pd.read_csv('/home/ksb/Downloads/data(1).csv')

x = df["Calories"].median()

df["Calories"].fillna(x, inplace = True) 
print(df.to_string())
# Out:
#     Duration  Pulse  Maxpulse  Calories        Date
# 0         60    110       130     409.1  01/01/2015
# 1         60    117       145     479.0  01/01/2015
# 2         60    103       135     340.0  02/01/2015
# 3         45    109       175     282.4  03/01/2015
# 4         45    117       148     406.0  04/01/2015
# 5         60    102       127     300.0  05/01/2015
# 6         60    110       136     374.0  06/01/2015
# 7         45    104       134     253.3  07/01/2015
# 8         30    109       133     195.1  08/01/2015
# 9         60     98       124     269.0  09/01/2015
# 10        60    103       147     329.3  10/01/2015
# 11        60    100       120     250.7  07/01/2015
# 12        60    106       128     345.3  12/01/2015
# 13        60    104       132     379.3  13/01/2015
# 14        60     98       123     275.0  14/01/2015
# 15        60     98       120     215.2  15/01/2015
# 16        60    100       120     300.0  15/01/2015
# ...

# %%
import pandas as pd

df = pd.read_csv('/home/ksb/Downloads/data(1).csv')

print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# dtype: bool

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('/home/ksb/Downloads/data(1).csv')

# Check the column names to ensure "Date" is correct
print("Columns in the DataFrame:", df.columns)

# Convert the "Date" column to datetime format if it exists
if "Date" in df.columns:
    df["Date"] = pd.to_datetime(df["Date"], errors='coerce')  # Use errors='coerce' to handle invalid dates
else:
    print('"Date" column not found in the DataFrame.')

# Print the entire DataFrame (or a subset if it's large)
print(df.to_string())
